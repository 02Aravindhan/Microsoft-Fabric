# %% [markdown]
# **Create simple data frame**

# %%
data = [("United States","US",40,44,42,126),
("China","CHN",40,27,24,91),
("Japan","JPN",20,12,13,45),
("Australia","AUS",18,19,16,53),
("France","FRA",16,26,22,64),
("Netherlands","NED",15,7,12,34),
("Great Britain","GBG",14,22,29,65),
("South Korea","KOR",13,9,10,32),
("Italy","ITA",12,13,15,40),
("Germany","GER",12,13,8,33),
("New Zealand","NZ",10,7,3,20)
]

columns = ["Country","Code","Gold","Sliver","Bronze","Total"]

df = spark.createDataFrame(data=data,schema=columns)
df.printSchema()
df.show()
# Out:
# StatementMeta(, 20b78c2e-1f34-49f0-b3a5-e26dbfae9796, 4, Finished, Available, Finished)
# root
#  |-- Country: string (nullable = true)
#  |-- Code: string (nullable = true)
#  |-- Gold: long (nullable = true)
#  |-- Sliver: long (nullable = true)
#  |-- Bronze: long (nullable = true)
#  |-- Total: long (nullable = true)
#
# +-------------+----+----+------+------+-----+
# |      Country|Code|Gold|Sliver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|  US|  40|    44|    42|  126|
# |        China| CHN|  40|    27|    24|   91|
# |        Japan| JPN|  20|    12|    13|   45|
# |    Australia| AUS|  18|    19|    16|   53|
# |       France| FRA|  16|    26|    22|   64|
# |  Netherlands| NED|  15|     7|    12|   34|
# |Great Britain| GBG|  14|    22|    29|   65|
# |  South Korea| KOR|  13|     9|    10|   32|
# |        Italy| ITA|  12|    13|    15|   40|
# |      Germany| GER|  12|    13|     8|   33|
# |  New Zealand|  NZ|  10|     7|     3|   20|
# +-------------+----+----+------+------+-----+

# %% [markdown]
# **schema and show**
#
#
# schema()= field
#
# show()=dataframe (table create)

# %% [markdown]
# **Display**
#
# display(df)

# %%
display(df)
# Out:
# StatementMeta(, 20b78c2e-1f34-49f0-b3a5-e26dbfae9796, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 0f9acfdd-4a43-46e0-9b87-51d01750a033)

# %% [markdown]
#  **data from type**

# %%
type(df)
# Out:
# StatementMeta(, 20b78c2e-1f34-49f0-b3a5-e26dbfae9796, 5, Finished, Available, Finished)
# pyspark.sql.dataframe.DataFrame

# %%
type(df.Country)
# Out:
# StatementMeta(, 20b78c2e-1f34-49f0-b3a5-e26dbfae9796, 8, Finished, Available, Finished)
# pyspark.sql.column.Column

# %%
type(df.Gold)
# Out:
# StatementMeta(, 20b78c2e-1f34-49f0-b3a5-e26dbfae9796, 9, Finished, Available, Finished)
# pyspark.sql.column.Column

# %% [markdown]
# **DataFrame using StructType**

# %% [markdown]
# ****

# %%
from pyspark.sql.types import StructType,StructField, StringType, IntegerType

data = [("United States","US",40,44,42,126),
("China","CHN",40,27,24,91),
("Japan","JPN",20,12,13,45),
("Australia","AUS",18,19,16,53),
("France","FRA",16,26,22,64),
("Netherlands","NED",15,7,12,34),
("Great Britain","GBG",14,22,29,65),
("South Korea","KOR",13,9,10,32),
("Italy","ITA",12,13,15,40),
("Germany","GER",12,13,8,33),
("New Zealand","NZ",10,7,3,20)
]

columns = StructType([
    StructField("Country",StringType(),True),
    StructField("code",StringType(),True),
    StructField("Gold", IntegerType(), True),
    StructField("Sliver", IntegerType(), True),
    StructField("Bronze", IntegerType(), True),
    StructField("Total", IntegerType(), True)
])

dfpyt=spark.createDataFrame(data=data,schema=columns)
dfpyt.printSchema()
dfpyt.show(truncate=False)
# Out:
# StatementMeta(, 20b78c2e-1f34-49f0-b3a5-e26dbfae9796, 15, Finished, Available, Finished)
# root
#  |-- Country: string (nullable = true)
#  |-- code: string (nullable = true)
#  |-- Gold: integer (nullable = true)
#  |-- Sliver: integer (nullable = true)
#  |-- Bronze: integer (nullable = true)
#  |-- Total: integer (nullable = true)
#
# +-------------+----+----+------+------+-----+
# |Country      |code|Gold|Sliver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|US  |40  |44    |42    |126  |
# |China        |CHN |40  |27    |24    |91   |
# |Japan        |JPN |20  |12    |13    |45   |
# |Australia    |AUS |18  |19    |16    |53   |
# |France       |FRA |16  |26    |22    |64   |
# |Netherlands  |NED |15  |7     |12    |34   |
# |Great Britain|GBG |14  |22    |29    |65   |
# |South Korea  |KOR |13  |9     |10    |32   |
# |Italy        |ITA |12  |13    |15    |40   |
# |Germany      |GER |12  |13    |8     |33   |
# |New Zealand  |NZ  |10  |7     |3     |20   |
# +-------------+----+----+------+------+-----+

# %% [markdown]
# **Dta Definition Language**
#
# ddl is string
#
# integer

# %%
columns_ddl = "Country STRING, Code STRING, Gold INT,Sliver INT,Bronze INT, Total INT"
df_with_ddl_schema = spark.createDataFrame(data=data,schema=columns_ddl)
df_with_ddl_schema.printSchema()
df_with_ddl_schema.show(truncate=False)
# Out:
# StatementMeta(, 20b78c2e-1f34-49f0-b3a5-e26dbfae9796, 12, Finished, Available, Finished)
# root
#  |-- Country: string (nullable = true)
#  |-- Code: string (nullable = true)
#  |-- Gold: integer (nullable = true)
#  |-- Sliver: integer (nullable = true)
#  |-- Bronze: integer (nullable = true)
#  |-- Total: integer (nullable = true)
#
# +-------------+----+----+------+------+-----+
# |Country      |Code|Gold|Sliver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|US  |40  |44    |42    |126  |
# |China        |CHN |40  |27    |24    |91   |
# |Japan        |JPN |20  |12    |13    |45   |
# |Australia    |AUS |18  |19    |16    |53   |
# |France       |FRA |16  |26    |22    |64   |
# |Netherlands  |NED |15  |7     |12    |34   |
# |Great Britain|GBG |14  |22    |29    |65   |
# |South Korea  |KOR |13  |9     |10    |32   |
# |Italy        |ITA |12  |13    |15    |40   |
# |Germany      |GER |12  |13    |8     |33   |
# |New Zealand  |NZ  |10  |7     |3     |20   |
# +-------------+----+----+------+------+-----+

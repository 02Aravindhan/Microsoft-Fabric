# %% [markdown]
# **Upload IPL Cricket dataset CSV file**

# %%
from pyspark.sql import SparkSession
 
file_path ='Files/data/ipl_summary_raw.csv'

df = spark.read.csv(file_path,header=True,inferSchema=True)

df.show(5)
# Out:
# StatementMeta(, 554d608f-dc00-4302-92c8-ca702bcdca63, 3, Finished, Available, Finished)
# +-------------------+---------+------------+-----------------------+--------------------+-----------+-------------------+-------------------------------+--------------------------------+---------------------------+------------------------+------------------------+--------------------+--------------------+----------+----------------------+-----------+--------------+--------------------+--------------------+------------------+--------------------+--------------------+-----------------------+-----------------------+-------------------+----------------+------------+-------------------+
# ...

# %% [markdown]
# **display**
#
#
#
# 2 type  1. head(first 5)    2. tail (last line 5)

# %%
display(df.head(5))
# Out:
# StatementMeta(, 8cedb8db-209c-4575-a105-41ed162996e2, 26, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 display(df.head(5))
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# **schema**

# %%
df.printSchema()
# Out:
# StatementMeta(, 8cedb8db-209c-4575-a105-41ed162996e2, 10, Finished, Available, Finished)
# root
#  |-- info_balls_per_over: integer (nullable = true)
#  |-- info_city: string (nullable = true)
#  |-- info_dates_1: date (nullable = true)
#  |-- info_event_match_number: double (nullable = true)
#  |-- info_event_name: string (nullable = true)
#  |-- info_gender: string (nullable = true)
#  |-- info_match_type: timestamp (nullable = true)
#  |-- info_officials_match_referees_1: string (nullable = true)
#  |-- info_officials_reserve_umpires_1: string (nullable = true)
#  |-- info_officials_tv_umpires_1: string (nullable = true)
#  |-- info_officials_umpires_1: string (nullable = true)
#  |-- info_officials_umpires_2: string (nullable = true)
#  |-- info_outcome_by_runs: double (nullable = true)
#  |-- info_outcome_winner: string (nullable = true)
#  |-- info_overs: integer (nullable = true)
#  |-- info_player_of_match_1: string (nullable = true)
# ...

# %% [markdown]
# **Basic Operation**

# %%
df.select("info_city", "info_teams_1", "info_teams_2").show()
# Out:
# StatementMeta(, 8cedb8db-209c-4575-a105-41ed162996e2, 12, Finished, Available, Finished)
# +---------+--------------------+--------------------+
# |info_city|        info_teams_1|        info_teams_2|
# +---------+--------------------+--------------------+
# |Hyderabad| Sunrisers Hyderabad|Royal Challengers...|
# |     Pune|Rising Pune Super...|      Mumbai Indians|
# |   Rajkot|       Gujarat Lions|Kolkata Knight Ri...|
# |   Indore|     Kings XI Punjab|Rising Pune Super...|
# |Bengaluru|Royal Challengers...|    Delhi Daredevils|
# |Hyderabad| Sunrisers Hyderabad|       Gujarat Lions|
# |   Mumbai|      Mumbai Indians|Kolkata Knight Ri...|
# |   Indore|     Kings XI Punjab|Royal Challengers...|
# |     Pune|Rising Pune Super...|    Delhi Daredevils|
# |   Mumbai|      Mumbai Indians| Sunrisers Hyderabad|
# |  Kolkata|Kolkata Knight Ri...|     Kings XI Punjab|
# |Bangalore|Royal Challengers...|      Mumbai Indians|
# |   Rajkot|       Gujarat Lions|Rising Pune Super...|
# ...

# %%
ara = df.select("info_city", "info_teams_1", "info_teams_2")
display(ara)
# Out:
# StatementMeta(, 8cedb8db-209c-4575-a105-41ed162996e2, 17, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 ara = df.select("info_city", "info_teams_1", "info_teams_2")
# ----> 2 display(ara)
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# **distint()**

# %%
df.select("info_city").distinct().show()
# Out:
# StatementMeta(, 8cedb8db-209c-4575-a105-41ed162996e2, 18, Finished, Available, Finished)
# +------------+
# |   info_city|
# +------------+
# |   Bangalore|
# |       Kochi|
# |     Chennai|
# |     Lucknow|
# | Navi Mumbai|
# |        null|
# |   Centurion|
# |      Ranchi|
# |      Mumbai|
# |   Ahmedabad|
# |      Durban|
# |     Kolkata|
# |   Cape Town|
# |  Dharamsala|
# |     Sharjah|
# |        Pune|
# |Johannesburg|
# |   Kimberley|
# |       Delhi|
# |      Raipur|
# +------------+
# only showing top 20 rows

# %% [markdown]
# **Filter**
#
# filter to separeter name example (chennai)

# %%
df.filter(df["info_city"]=='Chennai').show()
# Out:
# StatementMeta(, 8cedb8db-209c-4575-a105-41ed162996e2, 21, Finished, Available, Finished)
# +-------------------+---------+------------+-----------------------+--------------------+-----------+-------------------+-------------------------------+--------------------------------+---------------------------+------------------------+------------------------+--------------------+--------------------+----------+----------------------+-----------+--------------+--------------------+--------------------+------------------+--------------------+--------------------+-----------------------+-----------------------+-------------------+----------------+------------+-------------------+
# ...

# %%
fil_rows = df.filter(df["info_city"]=='Chennai')
display(fil_rows)
# Out:
# StatementMeta(, 8cedb8db-209c-4575-a105-41ed162996e2, 24, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 2
#       1 fil_rows = df.filter(df["info_city"]=='Chennai')
# ----> 2 display(fil_rows)
#
# TypeError: 'DataFrame' object is not callable

# %%
display(df)
# Out:
# StatementMeta(, 554d608f-dc00-4302-92c8-ca702bcdca63, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 8fb8a3e4-122c-4087-9707-1a2f851ad248)
